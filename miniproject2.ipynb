# %%
import psycopg2
import pandas as pd
import os
from dotenv import load_dotenv

load_dotenv()

DATABASE_URL = os.getenv("DATABASE_URL")

if not DATABASE_URL:
    raise RuntimeError("❌ DATABASE_URL is not set in your environment!")

print("DATABASE_URL loaded!")

def get_pg_connection():
    try:
        conn = psycopg2.connect(DATABASE_URL)
        print("✅ Connected to Postgres database")
        return conn
    except Exception as e:
        print("❌ Connection Error:", e)
        raise e

conn = get_pg_connection()
# Out:
# DATABASE_URL loaded!
# ✅ Connected to Postgres database

# %%
def run_sql(sql):
    try:
        df = pd.read_sql_query(sql, conn)
        print(f"✔ Query OK — {len(df)} rows")
        return df
    except Exception as e:
        print("❌ SQL Error:", e)

# %%
sql_test_1 = """
SELECT 
    r.regionid,
    r.region,
    c.countryid,
    c.country
FROM country c
JOIN region r ON c.regionid = r.regionid
ORDER BY r.region, c.country
LIMIT 20;
"""

df1 = run_sql(sql_test_1)
df1
# Out:
# C:\Users\91889\AppData\Local\Temp\ipykernel_3048\1635914683.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(sql, conn)
# ✔ Query OK — 20 rows
#     regionid           region  countryid    country
# 0          1    British Isles         10    Ireland
# 1          1    British Isles         19         UK
# 2          2  Central America         12     Mexico
# 3          3   Eastern Europe         14     Poland
# 4          4    North America          5     Canada
# 5          4    North America         20        USA
# 6          5  Northern Europe          6    Denmark
# 7          5  Northern Europe         17     Sweden
# 8          6      Scandinavia          7    Finland
# 9          6      Scandinavia         13     Norway
# 10         7    South America          1  Argentina
# 11         7    South America          4     Brazil
# 12         7    South America         21  Venezuela
# 13         8  Southern Europe         11      Italy
# 14         8  Southern Europe         15   Portugal
# 15         8  Southern Europe         16      Spain
# 16         9   Western Europe          2    Austria
# 17         9   Western Europe          3    Belgium
# 18         9   Western Europe          8     France
# 19         9   Western Europe          9    Germany

# %%
sql_test_2 = """
SELECT 
    c.customerid,
    c.firstname || ' ' || c.lastname AS customer_name,
    c.city,
    co.country,
    r.region
FROM customer c
JOIN country co ON c.countryid = co.countryid
JOIN region r ON co.regionid = r.regionid
ORDER BY c.customerid
LIMIT 20;
"""

df2 = run_sql(sql_test_2)
df2
# Out:
# ✔ Query OK — 20 rows
# C:\Users\91889\AppData\Local\Temp\ipykernel_3048\1635914683.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(sql, conn)
#     customerid       customer_name            city    country           region
# 0            1    Alejandra Camino          Madrid      Spain  Southern Europe
# 1            2     Alexander Feuer         Leipzig    Germany   Western Europe
# 2            3        Ana Trujillo     Mexico D.F.     Mexico  Central America
# 3            4   Anabela Domingues       Sao Paulo     Brazil    South America
# 4            5       Andre Fonseca        Campinas     Brazil    South America
# 5            6           Ann Devon          London         UK    British Isles
# 6            7      Annette Roulet        Toulouse     France   Western Europe
# 7            8      Antonio Moreno     Mexico D.F.     Mexico  Central America
# 8            9           Aria Cruz       Sao Paulo     Brazil    South America
# 9           10  Art Braunschweiger          Lander        USA    North America
# 10          11    Bernardo Batista  Rio de Janeiro     Brazil    South America
# 11          12      Carine Schmitt          Nantes     France   Western Europe
# 12          13     Carlos Gonzalez    Barquisimeto  Venezuela    South America
# 13          14    Carlos Hernandez   San Cristobal  Venezuela    South America
# 14          15     Catherine Dewey       Bruxelles    Belgium   Western Europe
# 15          16  Christina Berglund           Lulea     Sweden  Northern Europe
# 16          17       Daniel Tonini      Versailles     France   Western Europe
# 17          18          Diego Roel          Madrid      Spain  Southern Europe
# 18          19   Dominique Perrier           Paris     France   Western Europe
# 19          20    Eduardo Saavedra       Barcelona      Spain  Southern Europe

# %%
sql_test_3 = """
SELECT 
    p.productid,
    p.productname,
    p.productunitprice,
    pc.productcategory,
    pc.productcategorydescription
FROM product p
JOIN productcategory pc ON p.productcategoryid = pc.productcategoryid
ORDER BY p.productid
LIMIT 20;
"""

df3 = run_sql(sql_test_3)
df3
# Out:
# ✔ Query OK — 20 rows
# C:\Users\91889\AppData\Local\Temp\ipykernel_3048\1635914683.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(sql, conn)
#     productid                   productname  productunitprice productcategory  \
# 0           1                  Alice Mutton             39.00    Meat/Poultry
# 1           2                 Aniseed Syrup             10.00      Condiments
# 2           3              Boston Crab Meat             18.40         Seafood
# 3           4             Camembert Pierrot             34.00  Dairy Products
# 4           5              Carnarvon Tigers             62.50         Seafood
# 5           6                          Chai             18.00       Beverages
# 6           7                         Chang             19.00       Beverages
# 7           8              Chartreuse verte             18.00       Beverages
# 8           9  Chef Anton's Cajun Seasoning             22.00      Condiments
# 9          10        Chef Anton's Gumbo Mix             21.35      Condiments
# 10         11                     Chocolade             12.75     Confections
# 11         12                 Cote de Blaye            263.50       Beverages
# 12         13        Escargots de Bourgogne             13.25         Seafood
# 13         14                      Filo Mix              7.00  Grains/Cereals
# 14         15                   Flotemysost             21.50  Dairy Products
# 15         16                       Geitost              2.50  Dairy Products
# 16         17                  Genen Shouyu             15.50      Condiments
# 17         18        Gnocchi di nonna Alice             38.00  Grains/Cereals
# 18         19             Gorgonzola Telino             12.50  Dairy Products
# 19         20  Grandma's Boysenberry Spread             25.00      Condiments
#
#                            productcategorydescription
# 0                                      Prepared meats
# 1   Sweet and savory sauces, relishes, spreads, an...
# 2                                    Seaweed and fish
# 3                                             Cheeses
# 4                                    Seaweed and fish
# 5         Soft drinks, coffees, teas, beers, and ales
# 6         Soft drinks, coffees, teas, beers, and ales
# 7         Soft drinks, coffees, teas, beers, and ales
# 8   Sweet and savory sauces, relishes, spreads, an...
# 9   Sweet and savory sauces, relishes, spreads, an...
# 10                Desserts, candies, and sweet breads
# 11        Soft drinks, coffees, teas, beers, and ales
# 12                                   Seaweed and fish
# 13                Breads, crackers, pasta, and cereal
# 14                                            Cheeses
# 15                                            Cheeses
# 16  Sweet and savory sauces, relishes, spreads, an...
# 17                Breads, crackers, pasta, and cereal
# 18                                            Cheeses
# 19  Sweet and savory sauces, relishes, spreads, an...

# %%
sql_test_4 = """
SELECT 
    o.orderid,
    c.firstname || ' ' || c.lastname AS customer_name,
    p.productname,
    o.orderdate,
    o.quantityordered
FROM orderdetail o
JOIN customer c ON o.customerid = c.customerid
JOIN product p ON o.productid = p.productid
ORDER BY o.orderid
LIMIT 20;
"""

df4 = run_sql(sql_test_4)
df4
# Out:
# ✔ Query OK — 20 rows
# C:\Users\91889\AppData\Local\Temp\ipykernel_3048\1635914683.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(sql, conn)
#     orderid     customer_name                    productname   orderdate  \
# 0         1  Alejandra Camino     Teatime Chocolate Biscuits  2012-08-14
# 1         2  Alejandra Camino             Guarana Fantastica  2012-08-14
# 2         3  Alejandra Camino                 Steeleye Stout  2012-08-14
# 3         4  Alejandra Camino          Nord-Ost Matjeshering  2012-08-15
# 4         5  Alejandra Camino                 Ravioli Angelo  2012-08-15
# 5         6  Alejandra Camino          Nord-Ost Matjeshering  2012-09-16
# 6         7  Alejandra Camino                  Perth Pasties  2012-09-16
# 7         8  Alejandra Camino                      Tourtiere  2012-09-16
# 8         9  Alejandra Camino          Nord-Ost Matjeshering  2014-03-02
# 9        10  Alejandra Camino              Camembert Pierrot  2014-03-02
# 10       11  Alejandra Camino                       Tunnbrod  2014-04-09
# 11       12  Alejandra Camino  Singaporean Hokkien Fried Mee  2014-04-09
# 12       13  Alejandra Camino                    Rogede sild  2014-04-09
# 13       14  Alejandra Camino            Scottish Longbreads  2014-04-09
# 14       15  Alejandra Camino                    Flotemysost  2014-11-07
# 15       16  Alejandra Camino      Louisiana Hot Spiced Okra  2014-11-07
# 16       17  Alejandra Camino                      Chocolade  2014-11-07
# 17       18  Alejandra Camino               Carnarvon Tigers  2014-11-07
# 18       19  Alejandra Camino     Northwoods Cranberry Sauce  2014-11-07
# 19       20  Alejandra Camino                     Gravad lax  2014-11-07
#
#     quantityordered
# 0                 1
# 1                 6
# 2                 4
# 3                 6
# 4                 2
# 5                10
# 6                10
# 7                 5
# 8                 1
# 9                10
# 10               10
# 11                4
# 12               20
# 13                2
# 14               49
# 15               28
# 16               33
# 17                4
# 18               20
# 19                1

# %%
def check_empty(df, label):
    if df is None or len(df) == 0:
        print(f"❌ FAIL: {label} returned no rows")
    else:
        print(f"✅ PASS: {label} looks good ({len(df)} rows)")

check_empty(df1, "Region → Country Mapping")
check_empty(df2, "Customer table")
check_empty(df3, "Product + ProductCategory tables")
check_empty(df4, "OrderDetail full join")
# Out:
# ✅ PASS: Region → Country Mapping looks good (20 rows)
# ✅ PASS: Customer table looks good (20 rows)
# ✅ PASS: Product + ProductCategory tables looks good (20 rows)
# ✅ PASS: OrderDetail full join looks good (20 rows)
